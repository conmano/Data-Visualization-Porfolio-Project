# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('all_data.csv')

# %%
print(data.head())
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
import statsmodels 
import math

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# None

# %%
print(data.country.nunique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7089a173d6e6> in <module>
# ----> 1 print(data.country.nunique())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'country'

# %%
print(data.columns)
# Out:
# Index(['Country', 'Year', 'Life expectancy at birth (years)', 'GDP'], dtype='object')

# %%
print(data['Country'].nunique())
# Out:
# 6

# %%
plt.figure()
plt.subplot(1,2,1)
sns.boxplot(data = data, x = data['Country'], y = data['Life expectancy at birth (years)'])
plt.subplot(1,2,2)
sns.boxplot(data = data, x = data['Country'], y = data['GDP'])
plt.show()

# %%
plt.clf()

# %%
plt.figure()
plt.subplot(2,1,1)
sns.boxplot(data = data, x = data['Country'], y = data['Life expectancy at birth (years)'])
plt.subplot(2,2,2)
sns.boxplot(data = data, x = data['Country'], y = data['GDP'])
plt.show()

# %%
plt.clf()
plt.figure()
plt.subplot(2,1,1)
sns.boxplot(data = data, x = data['Country'], y = data['Life expectancy at birth (years)'])
plt.subplot(2,1,2)
sns.boxplot(data = data, x = data['Country'], y = data['GDP'])
plt.show()

# %%
plt.clf()
plt.figure(figsize = (15,15))
plt.subplot(1,2,1)
sns.boxplot(data = data, x = data['Country'], y = data['Life expectancy at birth (years)'])
plt.subplot(1,2,2)
sns.boxplot(data = data, x = data['Country'], y = data['GDP'])
plt.show()

# %%
plt.clf()
plt.figure(figsize = (15,15))
plt.subplot(1,2,1)
sns.boxplot(data = data, x = data['Country'], y = data['Life expectancy at birth (years)'])
plt.xticks(rotation = 45)
plt.subplot(1,2,2)
plt.xticks(rotation = 45)
plt.ylabel('GDP (10 Trillion)')
sns.boxplot(data = data, x = data['Country'], y = data['GDP'])
plt.show()

# %%
plt.savefig('Overall.png')

# %%
plt.clf()

# %%
countries = data['Country']
for i in range(len(countries))
    print(countries[i])
# Out:
#   File "<ipython-input-17-13d359712b34>", line 2
#     for i in range(len(countries))
#                                   ^
# SyntaxError: invalid syntax

# %%
for i in range(len(countries)):
    print(countries[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c088281b5436> in <module>
# ----> 1 for i in range(len(countries)):
#       2     print(countries[i])
#
# NameError: name 'countries' is not defined

# %%
countries = data['Country']
for i in range(len(countries)):
    print(countries[i])
# Out:
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# Chile
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# China
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# Mexico
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# United States of America
# ...

# %%
countries = data['Country'].unique()
for i in range(len(countries))
    print(countries[i])
# Out:
#   File "<ipython-input-20-5e1bb2f9d3f1>", line 2
#     for i in range(len(countries))
#                                   ^
# SyntaxError: invalid syntax

# %%
countries = data['Country'].unique()
for i in range(len(countries)):
    print(countries[i])
# Out:
# Chile
# China
# Germany
# Mexico
# United States of America
# Zimbabwe

# %%
for i in range(len(countries)):
    plt.figure(figsize = (10,10))
    plt.subplot(1,2,1)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['Life expectancy at birth (years)'][data['Country'] == countries[i]])
    plt.show()
    plt.clf()

# %%
for i in range(len(countries)):
    plt.figure(figsize = (10,10))
    plt.title(countries[i])
    plt.subplot(1,2,1)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['Life expectancy at birth (years)'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('Life expectancy')
    plt.subplot(1,2,2)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['GDP'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('GDP')
    plt.show()
    plt.clf()

# %%
for i in range(len(countries)):
    plt.figure(figsize = (10,10))
    plt.title(countries[i])
    plt.subplot(1,2,1)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['Life expectancy at birth (years)'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('Life expectancy')
    plt.subplot(1,2,2)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['GDP'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('GDP')
    plt.show()
    plt.clf()

# %%
for i in range(len(countries)):
    plt.figure(figsize = (10,10))
    plt.subplot(1,2,1)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['Life expectancy at birth (years)'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('Life expectancy')
    plt.title(countries[i] + ' Life expect')
    plt.subplot(1,2,2)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['GDP'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('GDP')
    plt.title(countries[i] + ' GDP')
    plt.show()
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-b3759146ddeb> in <module>
#       1 for i in range(len(countries)):
#       2     fig = plt.figure(figsize = (10,10))
# ----> 3     fig.title(countries[i])
#       4     plt.subplot(1,2,1)
#       5     plt.plot(data['Year'][data['Country'] == countries[i]], data['Life expectancy at birth (years)'][data['Country'] == countries[i]])
#
# AttributeError: 'Figure' object has no attribute 'title'

# %%
for i in range(len(countries)):
    plt.figure(figsize = (10,10))
    plt.subplot(1,2,1)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['Life expectancy at birth (years)'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('Life expectancy')
    plt.title(countries[i] + ' Life expect')
    plt.subplot(1,2,2)
    plt.plot(data['Year'][data['Country'] == countries[i]], data['GDP'][data['Country'] == countries[i]])
    plt.xlabel('Year')
    plt.ylabel('GDP')
    plt.title(countries[i] + ' GDP')
    plt.savefig(countries[i]+'.png')
    plt.show()
    plt.clf()

# %%
plt.figure(figsize = (15,15))
plt.subplot(1,2,1)
sns.boxplot(data = data, x = data['Country'], y = data['Life expectancy at birth (years)'])
plt.xticks(rotation = 45)
plt.subplot(1,2,2)
plt.xticks(rotation = 45)
plt.ylabel('GDP (10 Trillion)')
sns.boxplot(data = data, x = data['Country'], y = data['GDP'])
plt.savefig('Overall.png')
plt.show()
